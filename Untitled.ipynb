# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
im = cv2.imread('images/8.jpeg')
bbox, label, conf = cv.detect_common_objects(im)
print(label)
# Out:
# ['car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'car', 'person', 'car']

# %%
label = [objects for objects in label if (objects == 'car')]

# %%
output_image = draw_bbox(im, bbox, label, conf)

# %%
plt.imshow(output_image)
plt.show()

# %%
print('Number of cars in the image is '+ str(label.count('person')))
# Out:
# Number of cars in the image is 5

# %%
print(label)
# Out:
# ['bus', 'car', 'bus', 'car', 'car', 'bus', 'car', 'car', 'car', 'car', 'car', 'car', 'truck', 'car', 'car', 'person']
